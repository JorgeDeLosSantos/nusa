# %%
from nusa import *

# %%
fname = "src/data/truss_model.nusa"
m1 = read_truss_model(fname)
m1.solve()
m1.simple_report()
# Out:
# ...
#     NuSA Simple Report
# ...
#
# Model: Truss Model
# Number of nodes: 6
# Number of elements: 9
#
# RESULTS
#
# NODAL DISPLACEMENTS
# ======  ===========  ============
#   Node           UX            UY
# ======  ===========  ============
#      1   0.00165164    0.00030375
#      2   0.00165164  -7.59375e-05
#      3  0.000968203   0.000227813
#      4    0.0011032  -7.59375e-05
#      5            0             0
#      6      0.00027             0
# ======  ===========  ============
#
# NODAL FORCES
# ======  ===========  ============
#   Node           FX            FY
# ======  ===========  ============
#      1          900  -9.09495e-13
#      2            0   1.01282e-13
#      3          900  -5.68434e-13
#      4            0  -4.54747e-13
#      5        -1800         -2025
#      6  9.09495e-13          2025
# ======  ===========  ============
#
# ELEMENT FORCES
# =========  ===========
#   Element            F
# =========  ===========
#         1            0
# ...
